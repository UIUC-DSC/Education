# %% [markdown]
# # Intro to Pandas
# #### Illinois Data Science Club

# %% [markdown]
# This notebook will cover the basic facets of Python necessary for data science, as well as specific features of the pandas library. Given our time constraints, we won't be covering everything there is to know about Python, but we are confident that plenty is covered in these workshops for a successful data dive project to blossom. If you'd like to go above and beyond, documentation for the latest versions of [Python](https://docs.python.org/3/) and [pandas](https://pandas.pydata.org/docs/) are linked.

# %% [markdown]
# ## Python

# %% [markdown]
# Python is a programming language featuring constructs like variables and functions. Variables, much like in math, are objects that hold some value. For example,

# %%
# make x

...

# %% [markdown]
# Once we've made a variable, we can call it later in the code.

# %%
# print x

print(...)
# Out:
# Ellipsis

# %% [markdown]
# We just used `print`, a function! Functions are how we change variables and turn input into output. Functions typically take arguments in the form of variables. For example, the `print` function takes one variable as input and prints it out to the user.

# %% [markdown]
# There are quite a few different data types, all of which you will frequently see in your data analysis.

# %%
var1 = 'I love iDSC!'
type(var1)
# Out:
# str

# %% [markdown]
# We can use `type` to check the data type of a variable.

# %%
var2 = 67
type(var2)
# Out:
# int

# %%
var3 = 3.14
type(var3)
# Out:
# float

# %%
# make a boolean

idsc_is_the_best_data_science_organization_on_campus = ...
type(idsc_is_the_best_data_science_organization_on_campus)
# Out:
# ellipsis

# %% [markdown]
# We can compare variables using operations like `==`, `>`, `>=`, etc.

# %%
x = 10
y = 20

# %%
x == 10
# Out:
# True

# %%
x == 50
# Out:
# False

# %% [markdown]
# We can compare two variables as well.

# %%
# compare x and y

...
# Out:
# False

# %% [markdown]
# Understanding of these operators comes with lots of time and practice. A nice cheat sheet can be found [here](https://learnpython.com/blog/python-operators-cheat-sheet/).

# %% [markdown]
# ## Pandas

# %% [markdown]
# Now to get into some actual data science! Data science in Python is made much easier with the pandas library, a package of functions and features that allow us to import, format and transform data into an ideal format for modeling and visualizing.

# %% [markdown]
# We start by importing pandas (if for some reason you don't have pandas installed, you will get an error. Try running `pip install pandas`, `pip3 install pandas`, or `python3 install pandas` in your terminal). We typically import pandas "as pd", which means that anywhere we use a pandas feature, we can just write "pd" instead of "pandas".

# %%
# import pandas!!!!

...

# %% [markdown]
# We use the `read_csv` function to turn a `.csv` file into a pandas dataframe. This particular dataset contains the current batting leaders in the Women's Professional Baseball League 2026 season and was acquired [here](https://www.baseball-reference.com/register/leader.cgi?type=bat&id=b910b711#all_league_batting).

# %%
# reads a .csv file as a dataframe

df = ...

# %% [markdown]
# Now that we have our data in a dataframe, we can use pandas to explore it a little bit.

# %%
# displays the first 5 rows of the dataframe

...
# Out:
#    Rk              Name  Age   Tm  Lev  Aff   G  PA  AB   R  ...    OBP  \
# 0   1     Denae Benites   24  NYH  Wmn  NaN  13  56  48  20  ...  0.589
# 1   2  Suzuka Yamamoto*   27  BOS  Wmn  NaN   7  19  15   1  ...  0.632
# 2   3  Kelsie Whitmore#   27  SFF  Wmn  NaN  13  55  44  20  ...  0.564
# 3   4   Ashton Lansdell   25  LAQ  Wmn  NaN  13  52  38  18  ...  0.615
# 4   5   Elodie Ciamarro   19  NYH  Wmn  NaN   8  24  24   5  ...  0.458
#
#      SLG    OPS  TB  GDP  HBP  SH  SF  IBB              Name-additional
# 0  1.125  1.714  54  NaN    1   0   1    2  player.fcgi?id=benite000den
# 1  0.667  1.298  10  NaN    1   0   0    0  player.fcgi?id=yamamo000suz
# 2  1.205  1.768  53  NaN    1   0   1    2  player.fcgi?id=whitmo000kel
# 3  0.868  1.484  33  NaN    3   0   0    1  player.fcgi?id=lansde000ash
# 4  0.542  1.000  13  NaN    0   0   0    0  player.fcgi?id=ciamar000elo
#
# [5 rows x 30 columns]

# %%
# displays the last 5 rows of the dataframe

df.tail()
# Out:
#     Rk            Name  Age      Tm  Lev  Aff   G  PA  AB  R  ...    OBP  \
# 44  45   Raine Padgham   20     BOS  Wmn  NaN  12  35  30  5  ...  0.314
# 45  46  Ela Day-Bédard   21     SFF  Wmn  NaN  10  29  23  6  ...  0.310
# 46  47     Hyeonah Kim   26     BOS  Wmn  NaN  10  26  18  8  ...  0.400
# 47  48    Diana Ibarra   26  NYHLAQ  Wmn  NaN  11  27  22  1  ...  0.296
# 48  49       Jaida Lee   20     NYH  Wmn  NaN  10  15  13  3  ...  0.200
#
#       SLG    OPS  TB  GDP  HBP  SH  SF  IBB              Name-additional
# 44  0.200  0.514   6  NaN    0   0   0    0  player.fcgi?id=padgha000rai
# 45  0.174  0.484   4  NaN    4   0   1    0  player.fcgi?id=day-be000ela
# 46  0.222  0.622   4  NaN    4   1   0    0  player.fcgi?id=kim---021hye
# 47  0.136  0.433   3  NaN    2   0   0    0  player.fcgi?id=ibarra000dia
# 48  0.077  0.277   1  NaN    0   0   0    0  player.fcgi?id=lee---000jai
#
# [5 rows x 30 columns]

# %%
# displays the number of rows and columns

...
# Out:
# (49, 30)

# %% [markdown]
# This means there are 49 rows and 30 columns (or, 49 observations and 30 variables).

# %%
# provides summary statistics for each column

...
# Out:
#              Rk        Age  Aff          G         PA         AB          R  \
# count  49.00000  49.000000  0.0  49.000000  49.000000  49.000000  49.000000
# mean   25.00000  23.387755  NaN  10.795918  35.979592  29.632653   7.673469
# std    14.28869   3.812350  NaN   1.989342  12.157799  10.240227   4.913365
# min     1.00000  18.000000  NaN   6.000000  15.000000  13.000000   1.000000
# 25%    13.00000  20.000000  NaN  10.000000  26.000000  22.000000   4.000000
# 50%    25.00000  23.000000  NaN  11.000000  36.000000  30.000000   7.000000
# 75%    37.00000  25.000000  NaN  12.000000  45.000000  38.000000  10.000000
# max    49.00000  34.000000  NaN  13.000000  58.000000  49.000000  20.000000
#
#                H         2B    3B  ...         BA        OBP        SLG  \
# count  49.000000  49.000000  49.0  ...  49.000000  49.000000  49.000000
# mean   10.061224   1.734694   0.0  ...   0.328857   0.433286   0.465980
# ...

# %% [markdown]
# What if we want to examine a specific column?

# %%
# returns only the "Tm" column of df

...
# Out:
# 0        NYH
# 1        BOS
# 2        SFF
# 3        LAQ
# 4        NYH
# 5        SFF
# 6        NYH
# 7        SFF
# 8        SFF
# 9        LAQ
# 10       SFF
# 11       NYH
# 12       SFF
# 13       NYH
# 14       LAQ
# 15       BOS
# 16       LAQ
# 17       SFF
# 18       LAQ
# 19       LAQ
# 20       SFF
# 21       SFF
# 22       LAQ
# 23       LAQ
# 24       BOS
# 25       NYH
# 26       SFF
# 27       BOS
# 28       LAQ
# 29       NYH
# 30       NYH
# 31       BOS
# 32       NYH
# 33       NYH
# 34       LAQ
# 35       BOS
# 36       BOS
# 37       LAQ
# 38       NYH
# 39       BOS
# 40       BOS
# 41       LAQ
# 42       BOS
# 43       BOS
# 44       BOS
# 45       SFF
# 46       BOS
# 47    NYHLAQ
# 48       NYH
# Name: Tm, dtype: str

# %%
# displays how many players each team has

...
# Out:
# Tm
# BOS       13
# NYH       12
# LAQ       12
# SFF       11
# NYHLAQ     1
# Name: count, dtype: int64

# %% [markdown]
# I will now introduce one of the most useful features in pandas; filtering, which starts out simple but can get quite complex. For example, what if we want to find all players with batting averages above .400?

# %%
# gets all players with BA > 0.350

df[...]
# Out:
#     Rk                Name  Age   Tm  Lev  Aff   G  PA  AB   R  ...    OBP  \
# 0    1       Denae Benites   24  NYH  Wmn  NaN  13  56  48  20  ...  0.589
# 1    2    Suzuka Yamamoto*   27  BOS  Wmn  NaN   7  19  15   1  ...  0.632
# 2    3    Kelsie Whitmore#   27  SFF  Wmn  NaN  13  55  44  20  ...  0.564
# 3    4     Ashton Lansdell   25  LAQ  Wmn  NaN  13  52  38  18  ...  0.615
# 4    5     Elodie Ciamarro   19  NYH  Wmn  NaN   8  24  24   5  ...  0.458
# 5    6      Skylar Kaplan*   24  SFF  Wmn  NaN  12  50  44  14  ...  0.520
# 6    7   Claire O'Sullivan   31  NYH  Wmn  NaN  11  26  20   5  ...  0.500
# 7    8        Alexia Jorge   22  SFF  Wmn  NaN  11  45  34  14  ...  0.578
# 8    9  Samantha Gutierrez   23  SFF  Wmn  NaN   6  21  16   6  ...  0.571
# 9   10     Samaria Benítez   23  LAQ  Wmn  NaN  12  42  38   8  ...  0.476
# 10  11  Andréanne Leblanc#   24  SFF  Wmn  NaN  13  56  46  11  ...  0.518
# ...

# %%
# gets all players on the team NYH

df[...]
# Out:
#     Rk                Name  Age   Tm  Lev  Aff   G  PA  AB   R  ...    OBP  \
# 0    1       Denae Benites   24  NYH  Wmn  NaN  13  56  48  20  ...  0.589
# 4    5     Elodie Ciamarro   19  NYH  Wmn  NaN   8  24  24   5  ...  0.458
# 6    7   Claire O'Sullivan   31  NYH  Wmn  NaN  11  26  20   5  ...  0.500
# 11  12    Natsuki Yonetani   24  NYH  Wmn  NaN  13  58  49  19  ...  0.500
# 13  14      London Studer*   19  NYH  Wmn  NaN  12  39  36   7  ...  0.410
# 25  26       Kylee Lahners   33  NYH  Wmn  NaN  12  44  28   7  ...  0.545
# 29  30  Alyssa Zettlemoyer   19  NYH  Wmn  NaN  12  33  26   3  ...  0.424
# 30  31      Claire Eccles*   28  NYH  Wmn  NaN  11  34  30   7  ...  0.313
# 32  33         Keira Izumi   19  NYH  Wmn  NaN  11  29  24   4  ...  0.379
# 33  34      Madison Willan   25  NYH  Wmn  NaN  10  24  18   3  ...  0.417
# 38  39           Val Perez   34  NYH  Wmn  NaN   7  29  25   9  ...  0.310
# ...

# %% [markdown]
# We can also save these dataframes in other variables for later use.

# %%
# gets all players under 20 with at least 1 HR

df_filtered = df[...]      # note the parentheses!!

# %%
df_filtered
# Out:
#     Rk                 Name  Age   Tm  Lev  Aff   G  PA  AB  R  ...    OBP  \
# 32  33          Keira Izumi   19  NYH  Wmn  NaN  11  29  24  4  ...  0.379
# 37  38  Thaima Maximiliana#   19  LAQ  Wmn  NaN  12  28  25  4  ...  0.321
#
#       SLG    OPS  TB  GDP  HBP  SH  SF  IBB              Name-additional
# 32  0.458  0.838  11  NaN    2   0   1    0  player.fcgi?id=izumi-001kei
# 37  0.400  0.721  10  NaN    1   0   0    0  player.fcgi?id=maximi000tha
#
# [2 rows x 30 columns]

# %% [markdown]
# Finally, there are some interesting (self-explanatory) functions to find summary statistics of specific columns.

# %%
df['Age'].max()
# Out:
# np.int64(34)

# %%
df['Age'].min()
# Out:
# np.int64(18)

# %%
df['Age'].mean()
# Out:
# np.float64(23.387755102040817)

# %%
df['Age'].median()
# Out:
# np.float64(23.0)

# %% [markdown]
# For getting minimums and maximums, the following are usually preferred.

# %%
# get the 5 oldest players

df.nlargest(...)
# Out:
#     Rk               Name  Age   Tm  Lev  Aff   G  PA  AB   R  ...    OBP  \
# 38  39          Val Perez   34  NYH  Wmn  NaN   7  29  25   9  ...  0.310
# 25  26      Kylee Lahners   33  NYH  Wmn  NaN  12  44  28   7  ...  0.545
# 6    7  Claire O'Sullivan   31  NYH  Wmn  NaN  11  26  20   5  ...  0.500
# 22  23     Sarah Edwards#   30  LAQ  Wmn  NaN  11  41  33   6  ...  0.463
# 26  27  Amanda Gianelloni   29  SFF  Wmn  NaN  13  56  41  15  ...  0.436
#
#       SLG    OPS  TB  GDP  HBP  SH  SF  IBB              Name-additional
# 38  0.280  0.590   7  NaN    1   0   1    0  player.fcgi?id=perez-004val
# 25  0.536  1.081  15  NaN    6   0   1    0  player.fcgi?id=lahner000kyl
# 6   0.600  1.100  12  NaN    1   0   2    0  player.fcgi?id=osulli000cla
# 22  0.455  0.918  15  NaN    1   0   0    0  player.fcgi?id=edward000sar
# 26  0.415  0.851  17  NaN    2   1   3    0  player.fcgi?id=gianel000ama
#
# [5 rows x 30 columns]

# %%
# get the 5 youngest players

df.nsmallest(...)
# Out:
#     Rk             Name  Age   Tm  Lev  Aff   G  PA  AB  R  ...    OBP    SLG  \
# 23  24   Adelaide Frank   18  LAQ  Wmn  NaN   7  17  15  2  ...  0.412  0.333
# 41  42   Amira Hondras*   18  LAQ  Wmn  NaN  10  38  31  4  ...  0.342  0.290
# 42  43    Maïka Dumais*   18  BOS  Wmn  NaN  12  28  23  7  ...  0.357  0.261
# 4    5  Elodie Ciamarro   19  NYH  Wmn  NaN   8  24  24  5  ...  0.458  0.542
# 13  14   London Studer*   19  NYH  Wmn  NaN  12  39  36  7  ...  0.410  0.389
#
#       OPS  TB  GDP  HBP  SH  SF  IBB              Name-additional
# 23  0.745   5  NaN    0   0   0    0  player.fcgi?id=frank-000ade
# 41  0.632   9  NaN    1   0   1    0  player.fcgi?id=hondra000ami
# 42  0.618   6  NaN    0   0   0    0  player.fcgi?id=dumais000mai
# 4   1.000  13  NaN    0   0   0    0  player.fcgi?id=ciamar000elo
# 13  0.799  14  NaN    0   0   1    0  player.fcgi?id=studer000lon
#
# [5 rows x 30 columns]

# %% [markdown]
# ## Practice on your own!

# %%
# What is the median AB in the league? (column AB represents at-bats)

...
# Out:
# np.float64(30.0)

# %%
# What are the 7 players with the highest SLG? (column SLG represents slugging)

...
# Out:
#     Rk                Name  Age   Tm  Lev  Aff   G  PA  AB   R  ...    OBP  \
# 2    3    Kelsie Whitmore#   27  SFF  Wmn  NaN  13  55  44  20  ...  0.564
# 0    1       Denae Benites   24  NYH  Wmn  NaN  13  56  48  20  ...  0.589
# 3    4     Ashton Lansdell   25  LAQ  Wmn  NaN  13  52  38  18  ...  0.615
# 16  17        Jamie Mackay   23  LAQ  Wmn  NaN  13  46  40  14  ...  0.457
# 24  25      Lexi Hastings*   23  BOS  Wmn  NaN  10  32  24   7  ...  0.500
# 8    9  Samantha Gutierrez   23  SFF  Wmn  NaN   6  21  16   6  ...  0.571
# 12  13       Jill Albayati   22  SFF  Wmn  NaN   9  39  32  11  ...  0.513
#
#       SLG    OPS  TB  GDP  HBP  SH  SF  IBB              Name-additional
# 2   1.205  1.768  53  NaN    1   0   1    2  player.fcgi?id=whitmo000kel
# 0   1.125  1.714  54  NaN    1   0   1    2  player.fcgi?id=benite000den
# 3   0.868  1.484  33  NaN    3   0   0    1  player.fcgi?id=lansde000ash
# 16  0.800  1.257  32  NaN    4   0   0    0  player.fcgi?id=mackay000jam
# ...

# %%
# Find all players on team LAQ who have played at least 10 games (column G represents games played)

...
# Out:
#     Rk                 Name  Age   Tm  Lev  Aff   G  PA  AB   R  ...    OBP  \
# 3    4      Ashton Lansdell   25  LAQ  Wmn  NaN  13  52  38  18  ...  0.615
# 9   10      Samaria Benítez   23  LAQ  Wmn  NaN  12  42  38   8  ...  0.476
# 14  15       Caitlin Eynon*   23  LAQ  Wmn  NaN  10  34  31   7  ...  0.412
# 16  17         Jamie Mackay   23  LAQ  Wmn  NaN  13  46  40  14  ...  0.457
# 19  20       Michelle Roche   20  LAQ  Wmn  NaN  10  19  17   4  ...  0.421
# 22  23       Sarah Edwards#   30  LAQ  Wmn  NaN  11  41  33   6  ...  0.463
# 28  29          Maggie Foxx   20  LAQ  Wmn  NaN  13  46  39  11  ...  0.413
# 34  35          Mo'ne Davis   25  LAQ  Wmn  NaN  11  37  33   7  ...  0.351
# 37  38  Thaima Maximiliana#   19  LAQ  Wmn  NaN  12  28  25   4  ...  0.321
# 41  42       Amira Hondras*   18  LAQ  Wmn  NaN  10  38  31   4  ...  0.342
#
#       SLG    OPS  TB  GDP  HBP  SH  SF  IBB              Name-additional
# ...

# %%
# HARDER
# Which team has a higher average OPS; team NYH or SFF?

...
# Out:
# np.float64(0.8987499999999998)
